# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/adityasingh1993/100DayMLChallenge/blob/master/Stochastic_Gradient_Descent_From_SCratch.ipynb)

# %% [markdown]
# # Stochastic Gradient Descent

# %% [markdown]
# ### Pseudo Code For SGD

# %% [markdown]
# While True:
#
#
# > batch = next_training_batch(data, 256)
#
# > Wgradient = evaluate_gradient(loss, batch, W)
#
#
# > W += -alpha * Wgradient

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
def Sigmoid(X):
  return 1.0/(1.0+np.exp(-X))

# %%
def sigmoid_test():
  list2=[]
  list1=np.arange(-10,10,0.2)
  for i in range(0,len(list1)):
    list2.append(Sigmoid(list1[i]))
  plt.plot(list1,list2)

# %%
sigmoid_test()

# %%
def generate_Data():
  
  X,Y=make_blobs(n_samples=300,n_features=2,centers=2,cluster_std=1.5,random_state=20)
  return X,Y

# %%
X,Y=generate_Data()

# %% [markdown]
# ### Let's Visualize Our Data

# %%
plt.scatter(X[:,0],X[:,1])

# %%
def AddBiasToData(X):
  return np.c_[np.ones((X.shape[0])),X]

# %%
def initalize_Weight(x_shape):
  return np.random.uniform(size=(x_shape,))

# %%
def gen_BatchSize(x,y,batch_size):
  for i in np.arange(0,X.shape[0],batch_size):
    yield(x[i:i+batch_size],y[i:i+batch_size])

# %%
def Training(X,W,Y,epoch,alpha,batchsize):
  lossHistory=[]
  for i in range(0,epoch):
    epochloss=[]
    for(batchX,batchY) in gen_BatchSize(X,Y,batchsize):
      y=np.dot(batchX,W)
      pred=Sigmoid(y)
      error=pred-batchY
      loss=np.sum(error**2)
      epochloss.append(loss)
      print("Epoch loss is {} for Epoch #{}".format(loss,epoch))
      gradient=np.dot(batchX.T,error)
      W+=-alpha*gradient
    lossHistory.append(np.average(epochloss))
    print("Average loss is {}".format(np.average(epochloss)))
  return lossHistory,W

# %%
X_bias=AddBiasToData(X)
W=initalize_Weight(X_bias.shape[1])
lossHistory,W=Training(X_bias,W,Y,100,0.1,10)
# Out:
# Epoch loss is 4.0300093300036846 for Epoch #100
# Epoch loss is 2.999999983691141 for Epoch #100
# Epoch loss is 1.323195618675029 for Epoch #100
# Epoch loss is 2.84731356894911 for Epoch #100
# Epoch loss is 1.98183647685845 for Epoch #100
# Epoch loss is 2.1188532606208426e-05 for Epoch #100
# Epoch loss is 1.5520227655441668e-10 for Epoch #100
# Epoch loss is 0.9878492915208827 for Epoch #100
# Epoch loss is 0.5685667160378522 for Epoch #100
# Epoch loss is 0.0012276875553615103 for Epoch #100
# Epoch loss is 0.3280448221718448 for Epoch #100
# Epoch loss is 0.092122291596509 for Epoch #100
# Epoch loss is 0.03030640537409761 for Epoch #100
# Epoch loss is 4.053685908602388e-05 for Epoch #100
# Epoch loss is 3.53380174153946e-08 for Epoch #100
# Epoch loss is 0.048090042978764944 for Epoch #100
# Epoch loss is 1.8426907275582675e-05 for Epoch #100
# Epoch loss is 0.52757632809468 for Epoch #100
# Epoch loss is 9.71601380504081e-06 for Epoch #100
# Epoch loss is 3.7077856087181776e-08 for Epoch #100
# Epoch loss is 0.3970530644083167 for Epoch #100
# Epoch loss is 4.868632317345888e-09 for Epoch #100
# Epoch loss is 0.3299658076174408 for Epoch #100
# Epoch loss is 0.00021418396290214997 for Epoch #100
# Epoch loss is 0.02870877256055786 for Epoch #100
# Epoch loss is 3.7695353997481176e-07 for Epoch #100
# Epoch loss is 0.00037977878979441937 for Epoch #100
# Epoch loss is 1.842912774159755e-08 for Epoch #100
# Epoch loss is 0.8801351877286622 for Epoch #100
# Epoch loss is 2.0000890673130556 for Epoch #100
# Average loss is 0.6467591589007763
# Epoch loss is 0.001130434812994957 for Epoch #100
# Epoch loss is 3.1076970331390623e-07 for Epoch #100
# Epoch loss is 1.0268826774767144 for Epoch #100
# Epoch loss is 9.61323734385648e-07 for Epoch #100
# Epoch loss is 1.8230721469539226 for Epoch #100
# Epoch loss is 3.589291493129784 for Epoch #100
# Epoch loss is 1.7683172145895145 for Epoch #100
# Epoch loss is 0.9999788410556276 for Epoch #100
# Epoch loss is 0.07947892881832254 for Epoch #100
# Epoch loss is 1.8438635463981546e-06 for Epoch #100
# Epoch loss is 0.026207180586164613 for Epoch #100
# Epoch loss is 3.720405052031186e-05 for Epoch #100
# Epoch loss is 0.025711266450240532 for Epoch #100
# Epoch loss is 2.6830325048285284e-06 for Epoch #100
# Epoch loss is 1.6713214166896876e-10 for Epoch #100
# Epoch loss is 0.037996092010168035 for Epoch #100
# Epoch loss is 1.0344097844325733e-05 for Epoch #100
# Epoch loss is 0.29736383240879943 for Epoch #100
# Epoch loss is 1.1139932343540547e-09 for Epoch #100
# Epoch loss is 1.2923306162759466e-11 for Epoch #100
# Epoch loss is 0.015575858240676015 for Epoch #100
# Epoch loss is 1.3209250629542031e-07 for Epoch #100
# Epoch loss is 0.5977072923437569 for Epoch #100
# Epoch loss is 0.14079275030220925 for Epoch #100
# Epoch loss is 7.709484661588158e-07 for Epoch #100
# Epoch loss is 1.2814567436803625e-11 for Epoch #100
# Epoch loss is 2.6349169455099314e-05 for Epoch #100
# Epoch loss is 8.059755105918914e-09 for Epoch #100
# Epoch loss is 0.5469476166868112 for Epoch #100
# Epoch loss is 1.9971249844040453 for Epoch #100
# Average loss is 0.4324553072994884
# Epoch loss is 1.2684988257355134e-07 for Epoch #100
# Epoch loss is 1.1847529339706558e-07 for Epoch #100
# Epoch loss is 0.9890311567007204 for Epoch #100
# Epoch loss is 5.216431261079682e-10 for Epoch #100
# Epoch loss is 1.0741418185651042 for Epoch #100
# Epoch loss is 0.31130762351931146 for Epoch #100
# Epoch loss is 5.38333468897783e-12 for Epoch #100
# Epoch loss is 0.6104803197450903 for Epoch #100
# Epoch loss is 0.959673881494503 for Epoch #100
# Epoch loss is 5.125936789373678e-07 for Epoch #100
# Epoch loss is 0.010454232525900796 for Epoch #100
# Epoch loss is 2.008126897995593e-05 for Epoch #100
# Epoch loss is 0.030008245806595148 for Epoch #100
# Epoch loss is 1.7768812781942055e-06 for Epoch #100
# Epoch loss is 8.534831346387403e-11 for Epoch #100
# Epoch loss is 0.034682819116091605 for Epoch #100
# Epoch loss is 9.686895746400383e-06 for Epoch #100
# Epoch loss is 0.26672594963953966 for Epoch #100
# Epoch loss is 3.7122685459386654e-10 for Epoch #100
# Epoch loss is 5.189005997313031e-12 for Epoch #100
# Epoch loss is 0.009209533899033614 for Epoch #100
# Epoch loss is 1.0516020623438482e-07 for Epoch #100
# Epoch loss is 0.6342644957448629 for Epoch #100
# Epoch loss is 0.131217157787173 for Epoch #100
# Epoch loss is 5.643633256444443e-07 for Epoch #100
# Epoch loss is 4.689098436719559e-12 for Epoch #100
# Epoch loss is 2.0682505454707423e-05 for Epoch #100
# Epoch loss is 5.852451184160622e-09 for Epoch #100
# Epoch loss is 0.5197247766753119 for Epoch #100
# Epoch loss is 1.9970863804502457 for Epoch #100
# Average loss is 0.2526020684503087
# Epoch loss is 5.0115319587166364e-08 for Epoch #100
# Epoch loss is 1.0987578040855563e-07 for Epoch #100
# Epoch loss is 0.9883993219581959 for Epoch #100
# Epoch loss is 2.4600964900191747e-10 for Epoch #100
# Epoch loss is 1.0497768845620492 for Epoch #100
# Epoch loss is 0.1878811996441901 for Epoch #100
# Epoch loss is 6.247407520035395e-11 for Epoch #100
# Epoch loss is 0.24637056330978094 for Epoch #100
# Epoch loss is 0.9339809748979101 for Epoch #100
# Epoch loss is 7.232642438426605e-07 for Epoch #100
# Epoch loss is 0.01883548048873185 for Epoch #100
# Epoch loss is 1.4587743619693497e-05 for Epoch #100
# Epoch loss is 0.029044548602321762 for Epoch #100
# Epoch loss is 1.1406801268045249e-06 for Epoch #100
# Epoch loss is 4.72251085691471e-11 for Epoch #100
# Epoch loss is 0.029872859471753055 for Epoch #100
# Epoch loss is 9.403220233035238e-06 for Epoch #100
# Epoch loss is 0.2397641562125731 for Epoch #100
# Epoch loss is 1.4549917145746273e-10 for Epoch #100
# Epoch loss is 2.390799381212596e-12 for Epoch #100
# Epoch loss is 0.005874909752471456 for Epoch #100
# Epoch loss is 7.83715981638907e-08 for Epoch #100
# Epoch loss is 0.6540772796426627 for Epoch #100
# Epoch loss is 0.11927479889514812 for Epoch #100
# Epoch loss is 4.4055032577619153e-07 for Epoch #100
# Epoch loss is 1.9597485156394323e-12 for Epoch #100
# Epoch loss is 1.6654344398104907e-05 for Epoch #100
# Epoch loss is 4.397851570053031e-09 for Epoch #100
# Epoch loss is 0.4962654655001661 for Epoch #100
# Epoch loss is 1.997048056489727 for Epoch #100
# Average loss is 0.2332169897498912
# Epoch loss is 2.2653937070171884e-08 for Epoch #100
# Epoch loss is 1.0135813359630677e-07 for Epoch #100
# Epoch loss is 0.9879216191000061 for Epoch #100
# Epoch loss is 1.2704912079123837e-10 for Epoch #100
# Epoch loss is 1.0290711999546964 for Epoch #100
# Epoch loss is 0.11666889365151432 for Epoch #100
# Epoch loss is 2.7417274866174966e-10 for Epoch #100
# Epoch loss is 0.08777865472307245 for Epoch #100
# Epoch loss is 0.9019536817843297 for Epoch #100
# Epoch loss is 8.547856732271263e-07 for Epoch #100
# Epoch loss is 0.027193104290776263 for Epoch #100
# Epoch loss is 1.1591297899057156e-05 for Epoch #100
# Epoch loss is 0.026940119615754137 for Epoch #100
# Epoch loss is 7.513834886166268e-07 for Epoch #100
# Epoch loss is 2.782994617695997e-11 for Epoch #100
# Epoch loss is 0.02563314632858462 for Epoch #100
# Epoch loss is 9.060350403003298e-06 for Epoch #100
# Epoch loss is 0.21736704426876485 for Epoch #100
# Epoch loss is 6.406949849306133e-11 for Epoch #100
# Epoch loss is 1.2154511388511364e-12 for Epoch #100
# Epoch loss is 0.0039737590873781614 for Epoch #100
# Epoch loss is 5.695808437696986e-08 for Epoch #100
# Epoch loss is 0.6652981786346019 for Epoch #100
# Epoch loss is 0.1076060253956898 for Epoch #100
# Epoch loss is 3.5694678424256357e-07 for Epoch #100
# Epoch loss is 9.002046664259856e-13 for Epoch #100
# Epoch loss is 1.3644373703213416e-05 for Epoch #100
# Epoch loss is 3.383039304439722e-09 for Epoch #100
# Epoch loss is 0.4756675841372871 for Epoch #100
# Epoch loss is 1.9970095483463672 for Epoch #100
# Average loss is 0.22233730011017355
# Epoch loss is 1.1209316085304018e-08 for Epoch #100
# Epoch loss is 9.346358805660354e-08 for Epoch #100
# Epoch loss is 0.9875330124180425 for Epoch #100
# Epoch loss is 6.990538999630762e-11 for Epoch #100
# Epoch loss is 1.0107251234143115 for Epoch #100
# Epoch loss is 0.07418795834076103 for Epoch #100
# Epoch loss is 6.543206201101606e-10 for Epoch #100
# Epoch loss is 0.0367569402063007 for Epoch #100
# Epoch loss is 0.8943553386760713 for Epoch #100
# Epoch loss is 6.251935266927374e-07 for Epoch #100
# Epoch loss is 0.024962692981659457 for Epoch #100
# Epoch loss is 8.179261883410647e-06 for Epoch #100
# Epoch loss is 0.02828205301719077 for Epoch #100
# Epoch loss is 5.326651111942368e-07 for Epoch #100
# Epoch loss is 1.7290465588937445e-11 for Epoch #100
# Epoch loss is 0.022914337673887626 for Epoch #100
# Epoch loss is 8.548676148188093e-06 for Epoch #100
# Epoch loss is 0.19911447225242146 for Epoch #100
# Epoch loss is 3.0897363875695273e-11 for Epoch #100
# Epoch loss is 6.698726271253246e-13 for Epoch #100
# Epoch loss is 0.002810461708957625 for Epoch #100
# Epoch loss is 4.127205882168958e-08 for Epoch #100
# Epoch loss is 0.6715500190375782 for Epoch #100
# Epoch loss is 0.09699326077315129 for Epoch #100
# Epoch loss is 2.9701706869117947e-07 for Epoch #100
# Epoch loss is 4.478352217569665e-13 for Epoch #100
# Epoch loss is 1.1339738260306379e-05 for Epoch #100
# Epoch loss is 2.6589705870632966e-09 for Epoch #100
# Epoch loss is 0.4574003596997749 for Epoch #100
# Epoch loss is 1.9969689589894635 for Epoch #100
# Average loss is 0.21681948870396786
# Epoch loss is 5.981836610371432e-09 for Epoch #100
# Epoch loss is 8.631505657189722e-08 for Epoch #100
# Epoch loss is 0.9872122797717869 for Epoch #100
# Epoch loss is 4.057919614358165e-11 for Epoch #100
# Epoch loss is 0.9940605649498668 for Epoch #100
# Epoch loss is 0.04838457241700163 for Epoch #100
# Epoch loss is 1.0437064508074046e-09 for Epoch #100
# Epoch loss is 0.01927840865656644 for Epoch #100
# Epoch loss is 0.900170020313203 for Epoch #100
# Epoch loss is 3.919669718445177e-07 for Epoch #100
# Epoch loss is 0.019568670200268503 for Epoch #100
# Epoch loss is 5.7293942585214105e-06 for Epoch #100
# Epoch loss is 0.030588274244428698 for Epoch #100
# Epoch loss is 3.915444765720284e-07 for Epoch #100
# Epoch loss is 1.120802947803456e-11 for Epoch #100
# Epoch loss is 0.020770757167793575 for Epoch #100
# Epoch loss is 8.023025729607351e-06 for Epoch #100
# Epoch loss is 0.18341388451033785 for Epoch #100
# Epoch loss is 1.5991197534120316e-11 for Epoch #100
# Epoch loss is 3.939157969232964e-13 for Epoch #100
# Epoch loss is 0.002056634112893031 for Epoch #100
# Epoch loss is 3.008035340818517e-08 for Epoch #100
# Epoch loss is 0.6747336616134522 for Epoch #100
# Epoch loss is 0.08754854205792878 for Epoch #100
# Epoch loss is 2.5192120255468065e-07 for Epoch #100
# Epoch loss is 2.379204670954835e-13 for Epoch #100
# Epoch loss is 9.532870860847664e-06 for Epoch #100
# Epoch loss is 2.1278663995089013e-09 for Epoch #100
# Epoch loss is 0.44106663012020875 for Epoch #100
# Epoch loss is 1.99692648730172 for Epoch #100
# Average loss is 0.21352679445927286
# Epoch loss is 3.392096954511125e-09 for Epoch #100
# Epoch loss is 7.992736397330187e-08 for Epoch #100
# Epoch loss is 0.9869402411736471 for Epoch #100
# Epoch loss is 2.461931269904836e-11 for Epoch #100
# Epoch loss is 0.9787435096068475 for Epoch #100
# Epoch loss is 0.032332764092914024 for Epoch #100
# Epoch loss is 1.2754157376766717e-09 for Epoch #100
# Epoch loss is 0.012256584133101461 for Epoch #100
# Epoch loss is 0.9080078024697347 for Epoch #100
# Epoch loss is 2.434916003742457e-07 for Epoch #100
# Epoch loss is 0.014909429339123958 for Epoch #100
# Epoch loss is 4.233112650984592e-06 for Epoch #100
# Epoch loss is 0.032243405274968 for Epoch #100
# Epoch loss is 2.9209442263861765e-07 for Epoch #100
# Epoch loss is 7.524530715608813e-12 for Epoch #100
# Epoch loss is 0.018801989061848684 for Epoch #100
# Epoch loss is 7.522923615406135e-06 for Epoch #100
# Epoch loss is 0.1695585388214393 for Epoch #100
# Epoch loss is 8.751384748819439e-12 for Epoch #100
# Epoch loss is 2.439797118475247e-13 for Epoch #100
# Epoch loss is 0.0015461558097260577 for Epoch #100
# Epoch loss is 2.2121799040325333e-08 for Epoch #100
# Epoch loss is 0.6759515054838667 for Epoch #100
# Epoch loss is 0.07918374075642381 for Epoch #100
# Epoch loss is 2.1661599596612098e-07 for Epoch #100
# Epoch loss is 1.3336364947650904e-13 for Epoch #100
# Epoch loss is 8.086030142797035e-06 for Epoch #100
# Epoch loss is 1.7274091673785205e-09 for Epoch #100
# Epoch loss is 0.4263719677081971 for Epoch #100
# Epoch loss is 1.9968831560229916 for Epoch #100
# Average loss is 0.21112504975028717
# Epoch loss is 2.0175516208102703e-09 for Epoch #100
# Epoch loss is 7.426614848817843e-08 for Epoch #100
# Epoch loss is 0.9867002360568802 for Epoch #100
# Epoch loss is 1.5485782422364474e-11 for Epoch #100
# Epoch loss is 0.9646116567914034 for Epoch #100
# Epoch loss is 0.022094393909202325 for Epoch #100
# Epoch loss is 1.3047777909888959e-09 for Epoch #100
# Epoch loss is 0.009012678262034177 for Epoch #100
# Epoch loss is 0.9142684724508608 for Epoch #100
# Epoch loss is 1.5730414360122357e-07 for Epoch #100
# Epoch loss is 0.01158371073807875 for Epoch #100
# Epoch loss is 3.2966262723510587e-06 for Epoch #100
# Epoch loss is 0.03298950847528577 for Epoch #100
# Epoch loss is 2.1985304014761157e-07 for Epoch #100
# Epoch loss is 5.2005494258528945e-12 for Epoch #100
# Epoch loss is 0.016950908658481628 for Epoch #100
# Epoch loss is 7.0428468214210246e-06 for Epoch #100
# Epoch loss is 0.15723521455213976 for Epoch #100
# Epoch loss is 5.006995978143037e-12 for Epoch #100
# Epoch loss is 1.5755074072276846e-13 for Epoch #100
# Epoch loss is 0.0011877350239069332 for Epoch #100
# Epoch loss is 1.6427050127707338e-08 for Epoch #100
# Epoch loss is 0.6758541783378283 for Epoch #100
# Epoch loss is 0.07176484965163213 for Epoch #100
# Epoch loss is 1.8809793246615493e-07 for Epoch #100
# Epoch loss is 7.812302177338404e-14 for Epoch #100
# Epoch loss is 6.906928802284611e-06 for Epoch #100
# Epoch loss is 1.4180766182377494e-09 for Epoch #100
# Epoch loss is 0.4130965636999203 for Epoch #100
# Epoch loss is 1.996840096826038 for Epoch #100
# Average loss is 0.20914027035167462
# Epoch loss is 1.245720417492202e-09 for Epoch #100
# Epoch loss is 6.927478659497138e-08 for Epoch #100
# Epoch loss is 0.9864789274964688 for Epoch #100
# Epoch loss is 1.0035082673381162e-11 for Epoch #100
# Epoch loss is 0.951577850779421 for Epoch #100
# Epoch loss is 0.01540806166857491 for Epoch #100
# Epoch loss is 1.1840239405652965e-09 for Epoch #100
# Epoch loss is 0.007369484909447178 for Epoch #100
# Epoch loss is 0.918495183343482 for Epoch #100
# Epoch loss is 1.068346814180148e-07 for Epoch #100
# Epoch loss is 0.009311710466359925 for Epoch #100
# Epoch loss is 2.6648216140272378e-06 for Epoch #100
# Epoch loss is 0.033082372841666104 for Epoch #100
# Epoch loss is 1.6697505673600095e-07 for Epoch #100
# Epoch loss is 3.68194182195815e-12 for Epoch #100
# Epoch loss is 0.015250717635572062 for Epoch #100
# Epoch loss is 6.5746964016152186e-06 for Epoch #100
# Epoch loss is 0.14623751025034712 for Epoch #100
# Epoch loss is 2.9689263296048586e-12 for Epoch #100
# Epoch loss is 1.0524429042170051e-13 for Epoch #100
# Epoch loss is 0.0009283984941325484 for Epoch #100
# Epoch loss is 1.2311607164732452e-08 for Epoch #100
# Epoch loss is 0.6748329360877556 for Epoch #100
# Epoch loss is 0.06516127797655813 for Epoch #100
# Epoch loss is 1.644953992198823e-07 for Epoch #100
# Epoch loss is 4.7471372991946056e-14 for Epoch #100
# Epoch loss is 5.932188185720304e-06 for Epoch #100
# Epoch loss is 1.1742748772508443e-09 for Epoch #100
# Epoch loss is 0.4010723670116054 for Epoch #100
# Epoch loss is 1.9967983257774657 for Epoch #100
# Average loss is 0.20740069399858155
# Epoch loss is 7.921576312129081e-10 for Epoch #100
# Epoch loss is 6.488929784293329e-08 for Epoch #100
# Epoch loss is 0.9862659193373321 for Epoch #100
# Epoch loss is 6.666784146693392e-12 for Epoch #100
# Epoch loss is 0.9395866932232437 for Epoch #100
# Epoch loss is 0.010946071693643705 for Epoch #100
# Epoch loss is 9.903520687001807e-10 for Epoch #100
# Epoch loss is 0.0065062969208981225 for Epoch #100
# Epoch loss is 0.9210128437888715 for Epoch #100
# Epoch loss is 7.603342385193237e-08 for Epoch #100
# Epoch loss is 0.0077491636287032655 for Epoch #100
# Epoch loss is 2.206170428489135e-06 for Epoch #100
# Epoch loss is 0.032817213662619485 for Epoch #100
# Epoch loss is 1.280708274894401e-07 for Epoch #100
# Epoch loss is 2.659386359491447e-12 for Epoch #100
# Epoch loss is 0.01372480291607179 for Epoch #100
# Epoch loss is 6.116875883981992e-06 for Epoch #100
# Epoch loss is 0.1363843448448739 for Epoch #100
# Epoch loss is 1.8124970389290845e-12 for Epoch #100
# Epoch loss is 7.229341785911448e-14 for Epoch #100
# Epoch loss is 0.0007360681527320383 for Epoch #100
# Epoch loss is 9.305571608004577e-09 for Epoch #100
# Epoch loss is 0.6731347009480705 for Epoch #100
# Epoch loss is 0.05925971747986261 for Epoch #100
# Epoch loss is 1.445917165560036e-07 for Epoch #100
# Epoch loss is 2.975054309632693e-14 for Epoch #100
# Epoch loss is 5.1170659914183145e-06 for Epoch #100
# Epoch loss is 9.789494776873138e-10 for Epoch #100
# Epoch loss is 0.39016729355273116 for Epoch #100
# Epoch loss is 1.996758690950013 for Epoch #100
# Average loss is 0.2058354562291836
# Epoch loss is 5.156698639821975e-10 for Epoch #100
# Epoch loss is 6.104602652294016e-08 for Epoch #100
# Epoch loss is 0.9860531556850951 for Epoch #100
# Epoch loss is 4.523611224734537e-12 for Epoch #100
# Epoch loss is 0.9285956249728173 for Epoch #100
# Epoch loss is 0.007909366808565521 for Epoch #100
# Epoch loss is 7.836081689904085e-10 for Epoch #100
# Epoch loss is 0.006071057435564906 for Epoch #100
# Epoch loss is 0.922232054923276 for Epoch #100
# Epoch loss is 5.628329108595195e-08 for Epoch #100
# Epoch loss is 0.0066459292104634506 for Epoch #100
# Epoch loss is 1.854249983276762e-06 for Epoch #100
# Epoch loss is 0.032393817305286884 for Epoch #100
# Epoch loss is 9.921728610518073e-08 for Epoch #100
# Epoch loss is 1.953115021331037e-12 for Epoch #100
# Epoch loss is 0.012372407645884669 for Epoch #100
# Epoch loss is 5.671904290357263e-06 for Epoch #100
# Epoch loss is 0.1275136124757933 for Epoch #100
# Epoch loss is 1.1335696035710824e-12 for Epoch #100
# Epoch loss is 5.083344379379388e-14 for Epoch #100
# Epoch loss is 0.0005905268781034618 for Epoch #100
# Epoch loss is 7.0874037829884894e-09 for Epoch #100
# Epoch loss is 0.6709250306772044 for Epoch #100
# Epoch loss is 0.05396557563367971 for Epoch #100
# Epoch loss is 1.2756481755772293e-07 for Epoch #100
# Epoch loss is 1.9143169887070183e-14 for Epoch #100
# Epoch loss is 4.429111216207862e-06 for Epoch #100
# Epoch loss is 8.203904573768386e-10 for Epoch #100
# Epoch loss is 0.38027466576837227 for Epoch #100
# Epoch loss is 1.9967218747259092 for Epoch #100
# Average loss is 0.20440923362458932
# Epoch loss is 3.420556757421622e-10 for Epoch #100
# Epoch loss is 5.7685307483936524e-08 for Epoch #100
# Epoch loss is 0.9858343735444951 for Epoch #100
# Epoch loss is 3.125797657549279e-12 for Epoch #100
# Epoch loss is 0.91856668184473 for Epoch #100
# Epoch loss is 0.005805321960982412 for Epoch #100
# Epoch loss is 5.971223389849979e-10 for Epoch #100
# Epoch loss is 0.005895537249494903 for Epoch #100
# Epoch loss is 0.9224939975974616 for Epoch #100
# Epoch loss is 4.29969241532633e-08 for Epoch #100
# Epoch loss is 0.005840225202063653 for Epoch #100
# Epoch loss is 1.5740194869437142e-06 for Epoch #100
# Epoch loss is 0.03192101853991828 for Epoch #100
# Epoch loss is 7.759640462038657e-08 for Epoch #100
# Epoch loss is 1.4547369939898052e-12 for Epoch #100
# Epoch loss is 0.011178683926845871 for Epoch #100
# Epoch loss is 5.243287426253081e-06 for Epoch #100
# Epoch loss is 0.1194868761973382 for Epoch #100
# Epoch loss is 7.235444314730255e-13 for Epoch #100
# Epoch loss is 3.6461344386833837e-14 for Epoch #100
# Epoch loss is 0.000478545850269711 for Epoch #100
# Epoch loss is 5.435303322495283e-09 for Epoch #100
# Epoch loss is 0.6683204426276721 for Epoch #100
# Epoch loss is 0.04920057758014054 for Epoch #100
# Epoch loss is 1.1283914030321017e-07 for Epoch #100
# Epoch loss is 1.2602119378109258e-14 for Epoch #100
# Epoch loss is 3.8441812448752854e-06 for Epoch #100
# Epoch loss is 6.903203884984101e-10 for Epoch #100
# Epoch loss is 0.3713061669881185 for Epoch #100
# Epoch loss is 1.9966884116063288 for Epoch #100
# Average loss is 0.2031009273463983
# Epoch loss is 2.3038240982134795e-10 for Epoch #100
# Epoch loss is 5.475300560952802e-08 for Epoch #100
# Epoch loss is 0.985604658450029 for Epoch #100
# Epoch loss is 2.194573967986442e-12 for Epoch #100
# Epoch loss is 0.9094630240782238 for Epoch #100
# Epoch loss is 0.004323356369613501 for Epoch #100
# Epoch loss is 4.4374625894845567e-10 for Epoch #100
# Epoch loss is 0.005891755051509887 for Epoch #100
# Epoch loss is 0.9220571564268432 for Epoch #100
# Epoch loss is 3.3666410693843284e-08 for Epoch #100
# Epoch loss is 0.0052301106428030335 for Epoch #100
# Epoch loss is 1.3455911919553655e-06 for Epoch #100
# Epoch loss is 0.03144903383330133 for Epoch #100
# Epoch loss is 6.121502512084601e-08 for Epoch #100
# Epoch loss is 1.096649111399942e-12 for Epoch #100
# Epoch loss is 0.010124180491153977 for Epoch #100
# Epoch loss is 4.833989889574784e-06 for Epoch #100
# Epoch loss is 0.11218957737915494 for Epoch #100
# Epoch loss is 4.699520943830085e-13 for Epoch #100
# Epoch loss is 2.6604873305780695e-14 for Epoch #100
# Epoch loss is 0.00039117751510449073 for Epoch #100
# Epoch loss is 4.194429100911898e-09 for Epoch #100
# Epoch loss is 0.6654055148282465 for Epoch #100
# Epoch loss is 0.04489971689697743 for Epoch #100
# Epoch loss is 9.999816699340817e-08 for Epoch #100
# Epoch loss is 8.463435833265901e-15 for Epoch #100
# Epoch loss is 3.3438914288877885e-06 for Epoch #100
# Epoch loss is 5.827275293936564e-10 for Epoch #100
# Epoch loss is 0.3631870849701802 for Epoch #100
# Epoch loss is 1.9966587083608194 for Epoch #100
# Average loss is 0.20189616112847203
# Epoch loss is 1.5712371937054874e-10 for Epoch #100
# Epoch loss is 5.220094420644695e-08 for Epoch #100
# Epoch loss is 0.9853600999743672 for Epoch #100
# Epoch loss is 1.5626597014387795e-12 for Epoch #100
# Epoch loss is 0.9012476244652007 for Epoch #100
# Epoch loss is 0.0032636123734419344 for Epoch #100
# Epoch loss is 3.24481227411282e-10 for Epoch #100
# Epoch loss is 0.006009957110286756 for Epoch #100
# Epoch loss is 0.9211134889247412 for Epoch #100
# Epoch loss is 2.6867539236634345e-08 for Epoch #100
# Epoch loss is 0.004751084987834528 for Epoch #100
# Epoch loss is 1.1566565469322737e-06 for Epoch #100
# Epoch loss is 0.03099585469133631 for Epoch #100
# Epoch loss is 4.8669140171466907e-08 for Epoch #100
# Epoch loss is 8.35383461429386e-13 for Epoch #100
# Epoch loss is 0.00918980082959943 for Epoch #100
# Epoch loss is 4.4460310987668005e-06 for Epoch #100
# Epoch loss is 0.10552781756822258 for Epoch #100
# Epoch loss is 3.098907362990171e-13 for Epoch #100
# Epoch loss is 1.970572598008978e-14 for Epoch #100
# Epoch loss is 0.000322197732912122 for Epoch #100
# Epoch loss is 3.2553252080777048e-09 for Epoch #100
# Epoch loss is 0.662242811358747 for Epoch #100
# Epoch loss is 0.041008546208912526 for Epoch #100
# Epoch loss is 8.873106735064244e-08 for Epoch #100
# Epoch loss is 5.785206647223028e-15 for Epoch #100
# Epoch loss is 2.913946855433969e-06 for Epoch #100
# Epoch loss is 4.931369611276934e-10 for Epoch #100
# Epoch loss is 0.35585304913170307 for Epoch #100
# Epoch loss is 1.9966330625303008 for Epoch #100
# Average loss is 0.20078425817411996
# Epoch loss is 1.0828039874215473e-10 for Epoch #100
# Epoch loss is 4.998676983683523e-08 for Epoch #100
# Epoch loss is 0.9850975301129145 for Epoch #100
# Epoch loss is 1.1268528831233436e-12 for Epoch #100
# Epoch loss is 0.8938829316565489 for Epoch #100
# Epoch loss is 0.002495061471945438 for Epoch #100
# Epoch loss is 2.349707117859374e-10 for Epoch #100
# Epoch loss is 0.006219924940815486 for Epoch #100
# Epoch loss is 0.9198060004116532 for Epoch #100
# Epoch loss is 2.175804887319724e-08 for Epoch #100
# Epoch loss is 0.00436175726984942 for Epoch #100
# Epoch loss is 9.989218480367245e-07 for Epoch #100
# Epoch loss is 0.030563573111880033 for Epoch #100
# Epoch loss is 3.89646685685181e-08 for Epoch #100
# Epoch loss is 6.422327023708006e-13 for Epoch #100
# Epoch loss is 0.008358677081237035 for Epoch #100
# Epoch loss is 4.080551154170672e-06 for Epoch #100
# Epoch loss is 0.09942429852888966 for Epoch #100
# Epoch loss is 2.0707356416198223e-13 for Epoch #100
# Epoch loss is 1.4789951285914108e-14 for Epoch #100
# Epoch loss is 0.0002671737389439742 for Epoch #100
# Epoch loss is 2.539699681136246e-09 for Epoch #100
# Epoch loss is 0.6588792151470477 for Epoch #100
# Epoch loss is 0.037481004978198215 for Epoch #100
# Epoch loss is 7.879919693822732e-08 for Epoch #100
# Epoch loss is 4.017300769248982e-15 for Epoch #100
# Epoch loss is 2.5430268138349274e-06 for Epoch #100
# Epoch loss is 4.1814401381540376e-10 for Epoch #100
# Epoch loss is 0.3492477569332255 for Epoch #100
# Epoch loss is 1.9966116785095476 for Epoch #100
# Average loss is 0.19975681330680958
# Epoch loss is 7.52746447596178e-11 for Epoch #100
# Epoch loss is 4.807355107577466e-08 for Epoch #100
# Epoch loss is 0.9848143258455393 for Epoch #100
# Epoch loss is 8.219354507069239e-13 for Epoch #100
# Epoch loss is 0.8873309650470065 for Epoch #100
# Epoch loss is 0.0019303244926628617 for Epoch #100
# Epoch loss is 1.6928718398543314e-10 for Epoch #100
# Epoch loss is 0.0065019986808941815 for Epoch #100
# Epoch loss is 0.9182422931695224 for Epoch #100
# Epoch loss is 1.7819668272951672e-08 for Epoch #100
# Epoch loss is 0.004035142346797887 for Epoch #100
# Epoch loss is 8.663884392100979e-07 for Epoch #100
# Epoch loss is 0.030147396160744643 for Epoch #100
# Epoch loss is 3.13904928060729e-08 for Epoch #100
# Epoch loss is 4.977933216131542e-13 for Epoch #100
# Epoch loss is 0.00761654634506078 for Epoch #100
# Epoch loss is 3.7380009651846363e-06 for Epoch #100
# Epoch loss is 0.09381469110135394 for Epoch #100
# Epoch loss is 1.400058208700806e-13 for Epoch #100
# Epoch loss is 1.1232166237602066e-14 for Epoch #100
# Epoch loss is 0.00022288525199503183 for Epoch #100
# Epoch loss is 1.9909444318492597e-09 for Epoch #100
# Epoch loss is 0.6553502430155201 for Epoch #100
# Epoch loss is 0.0342777388148946 for Epoch #100
# Epoch loss is 7.001451568510049e-08 for Epoch #100
# Epoch loss is 2.829475603041399e-15 for Epoch #100
# Epoch loss is 2.2220220922852826e-06 for Epoch #100
# Epoch loss is 3.55108172829429e-10 for Epoch #100
# Epoch loss is 0.3433213636740709 for Epoch #100
# Epoch loss is 1.996594681394967 for Epoch #100
# Average loss is 0.1988069197214281
# Epoch loss is 5.27188005220929e-11 for Epoch #100
# Epoch loss is 4.642927075332184e-08 for Epoch #100
# Epoch loss is 0.9845082599195955 for Epoch #100
# Epoch loss is 6.058188826399681e-13 for Epoch #100
# Epoch loss is 0.8815535832191985 for Epoch #100
# Epoch loss is 0.0015102123489605975 for Epoch #100
# Epoch loss is 1.217550048094824e-10 for Epoch #100
# Epoch loss is 0.006842487653698678 for Epoch #100
# Epoch loss is 0.9165041467166372 for Epoch #100
# Epoch loss is 1.472122996869121e-08 for Epoch #100
# Epoch loss is 0.003753396789003503 for Epoch #100
# Epoch loss is 7.544888304473997e-07 for Epoch #100
# Epoch loss is 0.029740295610620002 for Epoch #100
# Epoch loss is 2.543152193746946e-08 for Epoch #100
# Epoch loss is 3.886858432671259e-13 for Epoch #100
# Epoch loss is 0.006951538253421526 for Epoch #100
# Epoch loss is 3.4183266882416752e-06 for Epoch #100
# Epoch loss is 0.08864476628506177 for Epoch #100
# Epoch loss is 9.566038822894028e-14 for Epoch #100
# Epoch loss is 8.621232193094625e-15 for Epoch #100
# Epoch loss is 0.00018695275813562914 for Epoch #100
# Epoch loss is 1.5677276190024025e-09 for Epoch #100
# Epoch loss is 0.6516831006918844 for Epoch #100
# Epoch loss is 0.031364811972599965 for Epoch #100
# Epoch loss is 6.222536204584851e-08 for Epoch #100
# Epoch loss is 2.0186245805279972e-15 for Epoch #100
# Epoch loss is 1.9435020101880663e-06 for Epoch #100
# Epoch loss is 3.0194739195928273e-10 for Epoch #100
# Epoch loss is 0.3380293206696183 for Epoch #100
# Epoch loss is 1.996582128959376 for Epoch #100
# Average loss is 0.19792870896726583
# Epoch loss is 3.7157307821614877e-11 for Epoch #100
# Epoch loss is 4.502629522294808e-08 for Epoch #100
# Epoch loss is 0.9841773875558951 for Epoch #100
# Epoch loss is 4.5083444758210053e-13 for Epoch #100
# Epoch loss is 0.8765127989754082 for Epoch #100
# Epoch loss is 0.0011940479844631353 for Epoch #100
# Epoch loss is 8.76331374746374e-11 for Epoch #100
# Epoch loss is 0.007231204041575239 for Epoch #100
# Epoch loss is 0.9146541617641313 for Epoch #100
# Epoch loss is 1.224347643219678e-08 for Epoch #100
# Epoch loss is 0.0035045883834761344 for Epoch #100
# Epoch loss is 6.596263395606113e-07 for Epoch #100
# Epoch loss is 0.029335254388495092 for Epoch #100
# Epoch loss is 2.0709804888407266e-08 for Epoch #100
# Epoch loss is 3.0552415228278677e-13 for Epoch #100
# Epoch loss is 0.0063537943941908565 for Epoch #100
# Epoch loss is 3.1211151881410086e-06 for Epoch #100
# Epoch loss is 0.08386823731646345 for Epoch #100
# Epoch loss is 6.59829527072386e-14 for Epoch #100
# Epoch loss is 6.681196890316458e-15 for Epoch #100
# Epoch loss is 0.00015759190067900317 for Epoch #100
# Epoch loss is 1.2396024878633514e-09 for Epoch #100
# Epoch loss is 0.6478988933640901 for Epoch #100
# Epoch loss is 0.02871271952984567 for Epoch #100
# Epoch loss is 5.530687776459999e-08 for Epoch #100
# Epoch loss is 1.4571088133129392e-15 for Epoch #100
# Epoch loss is 1.7013340519810002e-06 for Epoch #100
# Epoch loss is 2.569966355729268e-10 for Epoch #100
# Epoch loss is 0.3333315179643187 for Epoch #100
# Epoch loss is 1.996574022068804 for Epoch #100
# Average loss is 0.19711706122053632
# Epoch loss is 2.6334145101614953e-11 for Epoch #100
# Epoch loss is 4.384086279348866e-08 for Epoch #100
# Epoch loss is 0.9838199599886249 for Epoch #100
# Epoch loss is 3.3849159787726625e-13 for Epoch #100
# Epoch loss is 0.8721710779232971 for Epoch #100
# Epoch loss is 0.0009534986078151754 for Epoch #100
# Epoch loss is 6.323267406625747e-11 for Epoch #100
# Epoch loss is 0.007660086696120431 for Epoch #100
# Epoch loss is 0.9127404041761268 for Epoch #100
# Epoch loss is 1.023633227825958e-08 for Epoch #100
# Epoch loss is 0.0032806702394072873 for Epoch #100
# Epoch loss is 5.789098477025386e-07 for Epoch #100
# Epoch loss is 0.02892624661373915 for Epoch #100
# Epoch loss is 1.69445564078594e-08 for Epoch #100
# Epoch loss is 2.4162420751711366e-13 for Epoch #100
# Epoch loss is 0.0058150877252188355 for Epoch #100
# Epoch loss is 2.8457010028587772e-06 for Epoch #100
# Epoch loss is 0.0794451604151967 for Epoch #100
# Epoch loss is 4.5905525762166055e-14 for Epoch #100
# Epoch loss is 5.223409837935622e-15 for Epoch #100
# Epoch loss is 0.00013344718321310346 for Epoch #100
# Epoch loss is 9.839589959251673e-10 for Epoch #100
# Epoch loss is 0.6440142464715387 for Epoch #100
# Epoch loss is 0.026295623933943177 for Epoch #100
# Epoch loss is 4.9154436217322904e-08 for Epoch #100
# Epoch loss is 1.063149453115157e-15 for Epoch #100
# Epoch loss is 1.4904068737144966e-06 for Epoch #100
# Epoch loss is 2.1890839996008053e-10 for Epoch #100
# Epoch loss is 0.3291916348551737 for Epoch #100
# Epoch loss is 1.9965703137764348 for Epoch #100
# Average loss is 0.19636741650309428
# Epoch loss is 1.875405644743892e-11 for Epoch #100
# Epoch loss is 4.285261109183467e-08 for Epoch #100
# Epoch loss is 0.9834343582090823 for Epoch #100
# Epoch loss is 2.562501274676237e-13 for Epoch #100
# Epoch loss is 0.8684915910099347 for Epoch #100
# Epoch loss is 0.0007685803043955893 for Epoch #100
# Epoch loss is 4.5799597321496954e-11 for Epoch #100
# Epoch loss is 0.008122413470771589 for Epoch #100
# Epoch loss is 0.9107997193911849 for Epoch #100
# Epoch loss is 8.593843922483268e-09 for Epoch #100
# Epoch loss is 0.0030761808873513174 for Epoch #100
# Epoch loss is 5.099868034557513e-07 for Epoch #100
# Epoch loss is 0.028508572641190697 for Epoch #100
# Epoch loss is 1.3924772614864433e-08 for Epoch #100
# Epoch loss is 1.9216328590796612e-13 for Epoch #100
# Epoch loss is 0.005328496877852423 for Epoch #100
# Epoch loss is 2.5912436044392514e-06 for Epoch #100
# Epoch loss is 0.07534074615467756 for Epoch #100
# Epoch loss is 3.218911220397615e-14 for Epoch #100
# Epoch loss is 4.116771865769762e-15 for Epoch #100
# Epoch loss is 0.00011347698581095391 for Epoch #100
# Epoch loss is 7.838824275782862e-10 for Epoch #100
# Epoch loss is 0.6400425042071447 for Epoch #100
# Epoch loss is 0.024090758746417865 for Epoch #100
# Epoch loss is 4.3679046905022376e-08 for Epoch #100
# Epoch loss is 7.834280582687102e-16 for Epoch #100
# Epoch loss is 1.3064246792392438e-06 for Epoch #100
# Epoch loss is 1.8658124624914406e-10 for Epoch #100
# Epoch loss is 0.32557663316685714 for Epoch #100
# Epoch loss is 1.9965709172666573 for Epoch #100
# Average loss is 0.19567564890200645
# Epoch loss is 1.3413192983799201e-11 for Epoch #100
# Epoch loss is 4.2044151096585745e-08 for Epoch #100
# Epoch loss is 0.9830190420711246 for Epoch #100
# Epoch loss is 1.9549142522883471e-13 for Epoch #100
# Epoch loss is 0.8654384097784886 for Epoch #100
# Epoch loss is 0.0006250306950850064 for Epoch #100
# Epoch loss is 3.332893702804649e-11 for Epoch #100
# Epoch loss is 0.008612344692253388 for Epoch #100
# Epoch loss is 0.9088601616599629 for Epoch #100
# Epoch loss is 7.23904659932739e-09 for Epoch #100
# Epoch loss is 0.002887392638150675 for Epoch #100
# Epoch loss is 4.509288311693207e-07 for Epoch #100
# Epoch loss is 0.028078879106606072 for Epoch #100
# Epoch loss is 1.1490235422495102e-08 for Epoch #100
# Epoch loss is 1.5362105299643085e-13 for Epoch #100
# Epoch loss is 0.004888144513929839 for Epoch #100
# Epoch loss is 2.356783621423254e-06 for Epoch #100
# Epoch loss is 0.07152446513715383 for Epoch #100
# Epoch loss is 2.2734612425147145e-14 for Epoch #100
# Epoch loss is 3.2688281055858498e-15 for Epoch #100
# Epoch loss is 9.687259690253545e-05 for Epoch #100
# Epoch loss is 6.266328188219674e-10 for Epoch #100
# Epoch loss is 0.6359946203286136 for Epoch #100
# Epoch loss is 0.022077957274030877 for Epoch #100
# Epoch loss is 3.8804081422818814e-08 for Epoch #100
# Epoch loss is 5.82626808423889e-16 for Epoch #100
# Epoch loss is 1.1457517848371586e-06 for Epoch #100
# Epoch loss is 1.5910740301395887e-10 for Epoch #100
# Epoch loss is 0.3224563496210076 for Epoch #100
# Epoch loss is 1.9965757127833321 for Epoch #100
# Average loss is 0.19503798122570837
# Epoch loss is 9.630162498252282e-12 for Epoch #100
# Epoch loss is 4.140068917592423e-08 for Epoch #100
# Epoch loss is 0.9825725111955151 for Epoch #100
# Epoch loss is 1.5021992201207613e-13 for Epoch #100
# Epoch loss is 0.8629766433965469 for Epoch #100
# Epoch loss is 0.000512557019419386 for Epoch #100
# Epoch loss is 2.4383250426663214e-11 for Epoch #100
# Epoch loss is 0.009124659084146206 for Epoch #100
# Epoch loss is 0.9069428242086786 for Epoch #100
# Epoch loss is 6.11457621756815e-09 for Epoch #100
# Epoch loss is 0.002711744099491219 for Epoch #100
# Epoch loss is 4.001479094156793e-07 for Epoch #100
# Epoch loss is 0.027635036011717067 for Epoch #100
# Epoch loss is 9.518153452486839e-09 for Epoch #100
# Epoch loss is 1.2340112046407683e-13 for Epoch #100
# Epoch loss is 0.004488992855963611 for Epoch #100
# Epoch loss is 2.1412845606335324e-06 for Epoch #100
# Epoch loss is 0.06796936356892055 for Epoch #100
# Epoch loss is 1.616451252902922e-14 for Epoch #100
# Epoch loss is 2.6135047598938654e-15 for Epoch #100
# Epoch loss is 8.300027468962986e-05 for Epoch #100
# Epoch loss is 5.025545211926756e-10 for Epoch #100
# Epoch loss is 0.6318798216160761 for Epoch #100
# Epoch loss is 0.02023927507205182 for Epoch #100
# Epoch loss is 3.446289605355701e-08 for Epoch #100
# Epoch loss is 4.370107438044194e-16 for Epoch #100
# Epoch loss is 1.005293110621712e-06 for Epoch #100
# Epoch loss is 1.3573360661673264e-10 for Epoch #100
# Epoch loss is 0.31980315811185384 for Epoch #100
# Epoch loss is 1.9965845536546458 for Epoch #100
# Average loss is 0.19445092596880686
# Epoch loss is 6.938054687539528e-12 for Epoch #100
# Epoch loss is 4.0909695135208414e-08 for Epoch #100
# Epoch loss is 0.9820932750268772 for Epoch #100
# Epoch loss is 1.1621819841835704e-13 for Epoch #100
# Epoch loss is 0.8610725220922983 for Epoch #100
# Epoch loss is 0.0004236527352645976 for Epoch #100
# Epoch loss is 1.79411586960278e-11 for Epoch #100
# Epoch loss is 0.009654604110222512 for Epoch #100
# Epoch loss is 0.9050632532409654 for Epoch #100
# Epoch loss is 5.176695020187034e-09 for Epoch #100
# Epoch loss is 0.002547457433835721 for Epoch #100
# Epoch loss is 3.5633202860163365e-07 for Epoch #100
# Epoch loss is 0.027175958932929595 for Epoch #100
# Epoch loss is 7.913635912724652e-09 for Epoch #100
# Epoch loss is 9.957063393691348e-14 for Epoch #100
# Epoch loss is 0.004126685544751607 for Epoch #100
# Epoch loss is 1.9436644934575494e-06 for Epoch #100
# Epoch loss is 0.0646515294236084 for Epoch #100
# Epoch loss is 1.15645289731361e-14 for Epoch #100
# Epoch loss is 2.103008883087215e-15 for Epoch #100
# Epoch loss is 7.135919077035874e-05 for Epoch #100
# Epoch loss is 4.0428713864529667e-10 for Epoch #100
# Epoch loss is 0.6277061013263964 for Epoch #100
# Epoch loss is 0.018558683652077128 for Epoch #100
# Epoch loss is 3.059707096416469e-08 for Epoch #100
# Epoch loss is 3.30416117995639e-16 for Epoch #100
# Epoch loss is 8.824008368023357e-07 for Epoch #100
# Epoch loss is 1.1583130753969523e-10 for Epoch #100
# Epoch loss is 0.3175916824561492 for Epoch #100
# Epoch loss is 1.9965972715151703 for Epoch #100
# Average loss is 0.19391124347403335
# Epoch loss is 5.014301039670705e-12 for Epoch #100
# Epoch loss is 4.05606126577703e-08 for Epoch #100
# Epoch loss is 0.9815798300600148 for Epoch #100
# Epoch loss is 9.048906947292403e-14 for Epoch #100
# Epoch loss is 0.8596934343953557 for Epoch #100
# Epoch loss is 0.00035278840366181403 for Epoch #100
# Epoch loss is 1.3280262397701649e-11 for Epoch #100
# Epoch loss is 0.010197815145648055 for Epoch #100
# Epoch loss is 0.9032325634507071 for Epoch #100
# Epoch loss is 4.391394834729295e-09 for Epoch #100
# Epoch loss is 0.0023932783972919753 for Epoch #100
# Epoch loss is 3.1839436682693507e-07 for Epoch #100
# Epoch loss is 0.026701420282824077 for Epoch #100
# Epoch loss is 6.602808777505415e-09 for Epoch #100
# Epoch loss is 8.06784938164778e-14 for Epoch #100
# Epoch loss is 0.003797425447222002 for Epoch #100
# Epoch loss is 1.762820625176037e-06 for Epoch #100
# Epoch loss is 0.06154966793299385 for Epoch #100
# Epoch loss is 8.321545666151445e-15 for Epoch #100
# Epoch loss is 1.7023878774788505e-15 for Epoch #100
# Epoch loss is 6.155050738696768e-05 for Epoch #100
# Epoch loss is 3.261897889008807e-10 for Epoch #100
# Epoch loss is 0.623480584268968 for Epoch #100
# Epoch loss is 0.01702181880094047 for Epoch #100
# Epoch loss is 2.7155078999072723e-08 for Epoch #100
# Epoch loss is 2.5170002331386185e-16 for Epoch #100
# Epoch loss is 7.748004362685905e-07 for Epoch #100
# Epoch loss is 9.887362787266589e-11 for Epoch #100
# Epoch loss is 0.31579854672878455 for Epoch #100
# Epoch loss is 1.9966136808186434 for Epoch #100
# Average loss is 0.19341591132697686
# Epoch loss is 3.634460850709118e-12 for Epoch #100
# Epoch loss is 4.034460785164482e-08 for Epoch #100
# Epoch loss is 0.9810306427384828 for Epoch #100
# Epoch loss is 7.08821812764586e-14 for Epoch #100
# Epoch loss is 0.8588079266114274 for Epoch #100
# Epoch loss is 0.0002958521424428287 for Epoch #100
# Epoch loss is 9.890438193804905e-12 for Epoch #100
# Epoch loss is 0.010750275973737712 for Epoch #100
# Epoch loss is 0.9014583320417137 for Epoch #100
# Epoch loss is 3.7317925917090934e-09 for Epoch #100
# Epoch loss is 0.00224829941419623 for Epoch #100
# Epoch loss is 2.8543248545621507e-07 for Epoch #100
# Epoch loss is 0.026211870512071096 for Epoch #100
# Epoch loss is 5.5277782180098846e-09 for Epoch #100
# Epoch loss is 6.562683405965171e-14 for Epoch #100
# Epoch loss is 0.003497879809686804 for Epoch #100
# Epoch loss is 1.5976486252113396e-06 for Epoch #100
# Epoch loss is 0.05864475766633412 for Epoch #100
# Epoch loss is 6.020516113577397e-15 for Epoch #100
# Epoch loss is 1.3858204428745668e-15 for Epoch #100
# Epoch loss is 5.325437440697554e-05 for Epoch #100
# Epoch loss is 2.639177896593264e-10 for Epoch #100
# Epoch loss is 0.6192097942144551 for Epoch #100
# Epoch loss is 0.015615771308974354 for Epoch #100
# Epoch loss is 2.4091257772972734e-08 for Epoch #100
# Epoch loss is 1.9309357591402332e-16 for Epoch #100
# Epoch loss is 6.805312894363415e-07 for Epoch #100
# Epoch loss is 8.441727409973206e-11 for Epoch #100
# Epoch loss is 0.31440215465232724 for Epoch #100
# Epoch loss is 1.9966335827293415 for Epoch #100
# Average loss is 0.19296210106198128
# Epoch loss is 2.641393278915674e-12 for Epoch #100
# Epoch loss is 4.0254351473658925e-08 for Epoch #100
# Epoch loss is 0.9804441368895253 for Epoch #100
# Epoch loss is 5.584100333822387e-14 for Epoch #100
# Epoch loss is 0.8583856729541338 for Epoch #100
# Epoch loss is 0.00024975848450870696 for Epoch #100
# Epoch loss is 7.411261807109325e-12 for Epoch #100
# Epoch loss is 0.01130830358530886 for Epoch #100
# Epoch loss is 0.8997453229890342 for Epoch #100
# Epoch loss is 3.1763463377309095e-09 for Epoch #100
# Epoch loss is 0.002111839500570073 for Epoch #100
# Epoch loss is 2.566952813363863e-07 for Epoch #100
# Epoch loss is 0.025708278227436186 for Epoch #100
# Epoch loss is 4.64290331699497e-09 for Epoch #100
# Epoch loss is 5.357911056968655e-14 for Epoch #100
# Epoch loss is 0.0032251060425268524 for Epoch #100
# Epoch loss is 1.4470579321225728e-06 for Epoch #100
# Epoch loss is 0.055919767033601964 for Epoch #100
# Epoch loss is 4.378034966455796e-15 for Epoch #100
# Epoch loss is 1.1340526787053983e-15 for Epoch #100
# Epoch loss is 4.621263465391457e-05 for Epoch #100
# Epoch loss is 2.141092026655707e-10 for Epoch #100
# Epoch loss is 0.6148998466647797 for Epoch #100
# Epoch loss is 0.014328911073148775 for Epoch #100
# Epoch loss is 2.1364998922134865e-08 for Epoch #100
# Epoch loss is 1.4912317947298835e-16 for Epoch #100
# Epoch loss is 5.97898444308211e-07 for Epoch #100
# Epoch loss is 7.208815110040962e-11 for Epoch #100
# Epoch loss is 0.313382492381638 for Epoch #100
# Epoch loss is 1.9966567684739878 for Epoch #100
# Average loss is 0.1925471596107159
# Epoch loss is 1.9244702941744444e-12 for Epoch #100
# Epoch loss is 4.028383054855223e-08 for Epoch #100
# Epoch loss is 0.9798186848315433 for Epoch #100
# Epoch loss is 4.422944500977036e-14 for Epoch #100
# Epoch loss is 0.8583974241549777 for Epoch #100
# Epoch loss is 0.00021217215417416974 for Epoch #100
# Epoch loss is 5.587542315353861e-12 for Epoch #100
# Epoch loss is 0.011868546542672246 for Epoch #100
# Epoch loss is 0.8980960775253815 for Epoch #100
# Epoch loss is 2.707602805766414e-09 for Epoch #100
# Epoch loss is 0.001983363384563497 for Epoch #100
# Epoch loss is 2.315560986103425e-07 for Epoch #100
# Epoch loss is 0.025191992134828554 for Epoch #100
# Epoch loss is 3.912008962896725e-09 for Epoch #100
# Epoch loss is 4.3893687245482806e-14 for Epoch #100
# Epoch loss is 0.0029764930472936423 for Epoch #100
# Epoch loss is 1.30998383715257e-06 for Epoch #100
# Epoch loss is 0.05335941691405883 for Epoch #100
# Epoch loss is 3.1990350191983356e-15 for Epoch #100
# Epoch loss is 9.326034277597324e-16 for Epoch #100
# Epoch loss is 4.021569327788607e-05 for Epoch #100
# Epoch loss is 1.7415119259382697e-10 for Epoch #100
# Epoch loss is 0.6105565845130494 for Epoch #100
# Epoch loss is 0.01315073782517017 for Epoch #100
# Epoch loss is 1.894009523037375e-08 for Epoch #100
# Epoch loss is 1.158946002191478e-16 for Epoch #100
# Epoch loss is 5.254330206103823e-07 for Epoch #100
# Epoch loss is 6.156978694227784e-11 for Epoch #100
# Epoch loss is 0.31272095089717666 for Epoch #100
# Epoch loss is 1.9966830222293779 for Epoch #100
# Average loss is 0.1921685938302455
# Epoch loss is 1.4054276486278231e-12 for Epoch #100
# Epoch loss is 4.042818539521026e-08 for Epoch #100
# Epoch loss is 0.9791526014971449 for Epoch #100
# Epoch loss is 3.521178596983837e-14 for Epoch #100
# Epoch loss is 0.8588149414644499 for Epoch #100
# Epoch loss is 0.0001813110981390609 for Epoch #100
# Epoch loss is 4.238015037844661e-12 for Epoch #100
# Epoch loss is 0.012427990059115114 for Epoch #100
# Epoch loss is 0.8965113968907084 for Epoch #100
# Epoch loss is 2.311296472355437e-09 for Epoch #100
# Epoch loss is 0.0018624277122760355 for Epoch #100
# Epoch loss is 2.094907986339677e-07 for Epoch #100
# Epoch loss is 0.02466462470869692 for Epoch #100
# Epoch loss is 3.306282144459808e-09 for Epoch #100
# Epoch loss is 3.6075395707514817e-14 for Epoch #100
# Epoch loss is 0.0027497142819768736 for Epoch #100
# Epoch loss is 1.185396902931887e-06 for Epoch #100
# Epoch loss is 0.050949979146560555 for Epoch #100
# Epoch loss is 2.3482569306493676e-15 for Epoch #100
# Epoch loss is 7.704935813653999e-16 for Epoch #100
# Epoch loss is 3.5092458145964704e-05 for Epoch #100
# Epoch loss is 1.420048059562843e-10 for Epoch #100
# Epoch loss is 0.6061856701111253 for Epoch #100
# Epoch loss is 0.012071753386203298 for Epoch #100
# Epoch loss is 1.678420447075788e-08 for Epoch #100
# Epoch loss is 9.061188245861866e-17 for Epoch #100
# Epoch loss is 4.6185941092867783e-07 for Epoch #100
# Epoch loss is 5.259392567101241e-11 for Epoch #100
# Epoch loss is 0.31240016542405813 for Epoch #100
# Epoch loss is 1.9967121236133216 for Epoch #100
# Average loss is 0.19182405705431066
# Epoch loss is 1.028654361928233e-12 for Epoch #100
# Epoch loss is 4.068356843270918e-08 for Epoch #100
# Epoch loss is 0.9784441410735054 for Epoch #100
# Epoch loss is 2.8168713104165034e-14 for Epoch #100
# Epoch loss is 0.8596109219288437 for Epoch #100
# Epoch loss is 0.00015580472746940766 for Epoch #100
# Epoch loss is 3.233407320079649e-12 for Epoch #100
# Epoch loss is 0.012983963418624352 for Epoch #100
# Epoch loss is 0.8949907369615815 for Epoch #100
# Epoch loss is 1.975686024952779e-09 for Epoch #100
# Epoch loss is 0.0017486459258018044 for Epoch #100
# Epoch loss is 1.900598473047076e-07 for Epoch #100
# Epoch loss is 0.024127956075318733 for Epoch #100
# Epoch loss is 2.8026706061222e-09 for Epoch #100
# Epoch loss is 2.9739900093485704e-14 for Epoch #100
# Epoch loss is 0.002542689737539207 for Epoch #100
# Epoch loss is 1.0723101275198896e-06 for Epoch #100
# Epoch loss is 0.04867910341695315 for Epoch #100
# Epoch loss is 1.7312660852672915e-15 for Epoch #100
# Epoch loss is 6.393365232971508e-16 for Epoch #100
# Epoch loss is 3.0702568140053326e-05 for Epoch #100
# Epoch loss is 1.1607280705778622e-10 for Epoch #100
# Epoch loss is 0.60179264427451 for Epoch #100
# Epoch loss is 0.011083351548788832 for Epoch #100
# Epoch loss is 1.4868401128197919e-08 for Epoch #100
# Epoch loss is 7.125039525549494e-17 for Epoch #100
# Epoch loss is 4.060678948500111e-07 for Epoch #100
# Epoch loss is 4.493281635878924e-11 for Epoch #100
# Epoch loss is 0.312403870055327 for Epoch #100
# Epoch loss is 1.9967438498382775 for Epoch #100
# Average loss is 0.19151133701614015
# Epoch loss is 7.544798284122098e-13 for Epoch #100
# Epoch loss is 4.10470215183553e-08 for Epoch #100
# Epoch loss is 0.9776914957839961 for Epoch #100
# Epoch loss is 2.2638069437359754e-14 for Epoch #100
# Epoch loss is 0.8607589197939782 for Epoch #100
# Epoch loss is 0.00013459099063581532 for Epoch #100
# Epoch loss is 2.4811014230609768e-12 for Epoch #100
# Epoch loss is 0.013534146973309508 for Epoch #100
# Epoch loss is 0.8935325300921166 for Epoch #100
# Epoch loss is 1.6910547890374855e-09 for Epoch #100
# Epoch loss is 0.001641665927673341 for Epoch #100
# Epoch loss is 1.7289366709714838e-07 for Epoch #100
# Epoch loss is 0.023583856008533133 for Epoch #100
# Epoch loss is 2.382654593752562e-09 for Epoch #100
# Epoch loss is 2.4587275279978837e-14 for Epoch #100
# Epoch loss is 0.002353554728523959 for Epoch #100
# Epoch loss is 9.69784178053982e-07 for Epoch #100
# Epoch loss is 0.04653566703858167 for Epoch #100
# Epoch loss is 1.2817074512350506e-15 for Epoch #100
# Epoch loss is 5.326808146667738e-16 for Epoch #100
# Epoch loss is 2.6930341979907576e-05 for Epoch #100
# Epoch loss is 9.509945395531389e-11 for Epoch #100
# Epoch loss is 0.5973829604828995 for Epoch #100
# Epoch loss is 0.010177722562301034 for Epoch #100
# Epoch loss is 1.3166795601857412e-08 for Epoch #100
# Epoch loss is 5.633226067823792e-17 for Epoch #100
# Epoch loss is 3.570916142806096e-07 for Epoch #100
# Epoch loss is 3.839284656327946e-11 for Epoch #100
# Epoch loss is 0.31271676623167144 for Epoch #100
# Epoch loss is 1.9967779775787697 for Epoch #100
# Average loss is 0.19122834475762443
# Epoch loss is 5.545033118530359e-13 for Epoch #100
# Epoch loss is 4.1516368941653606e-08 for Epoch #100
# Epoch loss is 0.9768927965291883 for Epoch #100
# ...
# Epoch loss is 0.42234178621572627 for Epoch #100
# Epoch loss is 0.00013022920720357956 for Epoch #100
# Epoch loss is 2.0901666012587836e-11 for Epoch #100
# Epoch loss is 1.1874859854157858e-20 for Epoch #100
# Epoch loss is 4.4942270213752033e-10 for Epoch #100
# Epoch loss is 1.3044820545890898e-14 for Epoch #100
# Epoch loss is 0.5193554682639667 for Epoch #100
# Epoch loss is 1.9985825013220684 for Epoch #100
# Average loss is 0.18707948333456004
# Epoch loss is 4.0190121902682714e-19 for Epoch #100
# Epoch loss is 2.3789065899933622e-07 for Epoch #100
# Epoch loss is 0.8158747557099583 for Epoch #100
# Epoch loss is 1.5970908988366311e-18 for Epoch #100
# Epoch loss is 0.91811891143946 for Epoch #100
# Epoch loss is 3.253704218203147e-07 for Epoch #100
# Epoch loss is 2.1106822226524793e-17 for Epoch #100
# Epoch loss is 0.07621991152941876 for Epoch #100
# Epoch loss is 0.8493199977330932 for Epoch #100
# Epoch loss is 1.632396071542366e-12 for Epoch #100
# Epoch loss is 8.220082089959012e-05 for Epoch #100
# Epoch loss is 6.65763047145702e-09 for Epoch #100
# Epoch loss is 0.004224283881878948 for Epoch #100
# Epoch loss is 3.963044601484352e-12 for Epoch #100
# Epoch loss is 4.760204624813758e-18 for Epoch #100
# Epoch loss is 0.00012199367385990974 for Epoch #100
# Epoch loss is 7.013103256069841e-09 for Epoch #100
# Epoch loss is 0.003672958865722962 for Epoch #100
# Epoch loss is 3.7593680113099246e-21 for Epoch #100
# Epoch loss is 3.153131342168935e-19 for Epoch #100
# Epoch loss is 1.5754984628216928e-07 for Epoch #100
# Epoch loss is 2.073396079552529e-14 for Epoch #100
# Epoch loss is 0.42149844161992966 for Epoch #100
# Epoch loss is 0.00012316351000996533 for Epoch #100
# Epoch loss is 1.9379223647824135e-11 for Epoch #100
# Epoch loss is 1.0909065827295627e-20 for Epoch #100
# Epoch loss is 4.1259260867535924e-10 for Epoch #100
# Epoch loss is 1.1888166283983521e-14 for Epoch #100
# Epoch loss is 0.5218660058641873 for Epoch #100
# Epoch loss is 1.9985881734161337 for Epoch #100
# Average loss is 0.18699038443279378
# Epoch loss is 3.459336238997359e-19 for Epoch #100
# Epoch loss is 2.414940202960241e-07 for Epoch #100
# Epoch loss is 0.8122426175076696 for Epoch #100
# Epoch loss is 1.4065671464748644e-18 for Epoch #100
# Epoch loss is 0.9147078811261857 for Epoch #100
# Epoch loss is 2.965148696864441e-07 for Epoch #100
# Epoch loss is 1.7943119741817444e-17 for Epoch #100
# Epoch loss is 0.07907404036820326 for Epoch #100
# Epoch loss is 0.8495578515246369 for Epoch #100
# Epoch loss is 1.510357550626833e-12 for Epoch #100
# Epoch loss is 7.941487704701345e-05 for Epoch #100
# Epoch loss is 6.484288599420557e-09 for Epoch #100
# Epoch loss is 0.0041120140243189355 for Epoch #100
# Epoch loss is 3.705578181414946e-12 for Epoch #100
# Epoch loss is 4.3010737589465134e-18 for Epoch #100
# Epoch loss is 0.0001190283709208576 for Epoch #100
# Epoch loss is 6.6444456853347756e-09 for Epoch #100
# Epoch loss is 0.00351085556201582 for Epoch #100
# Epoch loss is 3.2923060055479476e-21 for Epoch #100
# Epoch loss is 2.9016752876337866e-19 for Epoch #100
# Epoch loss is 1.4820075861098214e-07 for Epoch #100
# Epoch loss is 1.9074778953474964e-14 for Epoch #100
# Epoch loss is 0.4207232161973041 for Epoch #100
# Epoch loss is 0.0001165635249943683 for Epoch #100
# Epoch loss is 1.7994526093178603e-11 for Epoch #100
# Epoch loss is 1.0036684958347731e-20 for Epoch #100
# Epoch loss is 3.792327511022548e-10 for Epoch #100
# Epoch loss is 1.0853554630515331e-14 for Epoch #100
# Epoch loss is 0.524273788710412 for Epoch #100
# Epoch loss is 1.998593186994295 for Epoch #100
# Average loss is 0.1869037052842953
# Epoch loss is 2.9871343428929778e-19 for Epoch #100
# Epoch loss is 2.4495956392395634e-07 for Epoch #100
# Epoch loss is 0.8086557481029542 for Epoch #100
# Epoch loss is 1.2403345827990719e-18 for Epoch #100
# Epoch loss is 0.9112218194579745 for Epoch #100
# Epoch loss is 2.70418394715002e-07 for Epoch #100
# Epoch loss is 1.527875680807171e-17 for Epoch #100
# Epoch loss is 0.08201118578958863 for Epoch #100
# Epoch loss is 0.849846078437599 for Epoch #100
# Epoch loss is 1.3990395130351743e-12 for Epoch #100
# Epoch loss is 7.675652187454844e-05 for Epoch #100
# Epoch loss is 6.32073111177059e-09 for Epoch #100
# Epoch loss is 0.004003183697591595 for Epoch #100
# Epoch loss is 3.468559001331478e-12 for Epoch #100
# Epoch loss is 3.891645700025384e-18 for Epoch #100
# Epoch loss is 0.00011621585834525902 for Epoch #100
# Epoch loss is 6.301305422865203e-09 for Epoch #100
# Epoch loss is 0.003355438951473565 for Epoch #100
# Epoch loss is 2.890368075141096e-21 for Epoch #100
# Epoch loss is 2.6736394331323696e-19 for Epoch #100
# Epoch loss is 1.3947240257243466e-07 for Epoch #100
# Epoch loss is 1.7579899270878643e-14 for Epoch #100
# Epoch loss is 0.42001486875181393 for Epoch #100
# Epoch loss is 0.00011039453626883442 for Epoch #100
# Epoch loss is 1.6733594522942062e-11 for Epoch #100
# Epoch loss is 9.247688706142028e-21 for Epoch #100
# Epoch loss is 3.489853230088258e-10 for Epoch #100
# Epoch loss is 9.926700448205789e-15 for Epoch #100
# Epoch loss is 0.5265792622048011 for Epoch #100
# Epoch loss is 1.998597558558094 for Epoch #100
# Average loss is 0.1868196392903797
# Epoch loss is 2.587561045394789e-19 for Epoch #100
# Epoch loss is 2.4828337694330895e-07 for Epoch #100
# Epoch loss is 0.8051170227128466 for Epoch #100
# Epoch loss is 1.095147587052985e-18 for Epoch #100
# Epoch loss is 0.9076676950210611 for Epoch #100
# Epoch loss is 2.4681228006250006e-07 for Epoch #100
# Epoch loss is 1.3032035927025914e-17 for Epoch #100
# Epoch loss is 0.08502948595042424 for Epoch #100
# Epoch loss is 0.8501826651176777 for Epoch #100
# Epoch loss is 1.2974026204956496e-12 for Epoch #100
# Epoch loss is 7.421956527411013e-05 for Epoch #100
# Epoch loss is 6.166341371364701e-09 for Epoch #100
# Epoch loss is 0.0038977065071759904 for Epoch #100
# Epoch loss is 3.2501547060131076e-12 for Epoch #100
# Epoch loss is 3.526091386443209e-18 for Epoch #100
# Epoch loss is 0.0001135470971378818 for Epoch #100
# Epoch loss is 5.981628154330115e-09 for Epoch #100
# Epoch loss is 0.0032064649893061054 for Epoch #100
# Epoch loss is 2.5436865353736697e-21 for Epoch #100
# Epoch loss is 2.4666157831671536e-19 for Epoch #100
# Epoch loss is 1.313196145649944e-07 for Epoch #100
# Epoch loss is 1.623094203536872e-14 for Epoch #100
# Epoch loss is 0.41937206706908536 for Epoch #100
# Epoch loss is 0.00010462458668946964 for Epoch #100
# Epoch loss is 1.5583977322280654e-11 for Epoch #100
# Epoch loss is 8.533132367828894e-21 for Epoch #100
# Epoch loss is 3.2153179588186036e-10 for Epoch #100
# Epoch loss is 9.095114892037498e-15 for Epoch #100
# Epoch loss is 0.5287830801914086 for Epoch #100
# Epoch loss is 1.9986013041401973 for Epoch #100
# Average loss is 0.18673835072844047
# Epoch loss is 2.248453537741866e-19 for Epoch #100
# Epoch loss is 2.514621537726032e-07 for Epoch #100
# Epoch loss is 0.8016290793741548 for Epoch #100
# Epoch loss is 9.682085431019792e-19 for Epoch #100
# Epoch loss is 0.9040522009347554 for Epoch #100
# Epoch loss is 2.2545316082567747e-07 for Epoch #100
# Epoch loss is 1.113495403951071e-17 for Epoch #100
# Epoch loss is 0.08812682381467202 for Epoch #100
# Epoch loss is 0.8505653794334066 for Epoch #100
# Epoch loss is 1.2045165716616673e-12 for Epoch #100
# Epoch loss is 7.179819283757976e-05 for Epoch #100
# Epoch loss is 6.020540398539291e-09 for Epoch #100
# Epoch loss is 0.0037954994548804744 for Epoch #100
# Epoch loss is 3.048712206933608e-12 for Epoch #100
# Epoch loss is 3.199310017025092e-18 for Epoch #100
# Epoch loss is 0.00011101356615238836 for Epoch #100
# Epoch loss is 5.683537263184745e-09 for Epoch #100
# Epoch loss is 0.0030636977636844657 for Epoch #100
# Epoch loss is 2.243934418018403e-21 for Epoch #100
# Epoch loss is 2.2784624666707915e-19 for Epoch #100
# Epoch loss is 1.237008247047035e-07 for Epoch #100
# Epoch loss is 1.5011764973504003e-14 for Epoch #100
# Epoch loss is 0.41879339044486646 for Epoch #100
# Epoch loss is 9.9224251443922e-05 for Epoch #100
# Epoch loss is 1.4534574599240705e-11 for Epoch #100
# Epoch loss is 7.885115356611599e-21 for Epoch #100
# Epoch loss is 2.965884163397998e-10 for Epoch #100
# Epoch loss is 8.347867337677935e-15 for Epoch #100
# Epoch loss is 0.5308860933928516 for Epoch #100
# Epoch loss is 1.9986044392938538 for Epoch #100
# Average loss is 0.18665997508510587
# Epoch loss is 1.9598268765099552e-19 for Epoch #100
# Epoch loss is 2.5449318674856485e-07 for Epoch #100
# Epoch loss is 0.798194319685453 for Epoch #100
# Epoch loss is 8.571046438390587e-19 for Epoch #100
# Epoch loss is 0.9003817401792877 for Epoch #100
# Epoch loss is 2.0612085906544872e-07 for Epoch #100
# Epoch loss is 9.530871090231528e-18 for Epoch #100
# Epoch loss is 0.0913008413571617 for Epoch #100
# Epoch loss is 0.8509918000409157 for Epoch #100
# Epoch loss is 1.1195478571418832e-12 for Epoch #100
# Epoch loss is 6.948693548938874e-05 for Epoch #100
# Epoch loss is 5.882784508052119e-09 for Epoch #100
# Epoch loss is 0.003696482518226348 for Epoch #100
# Epoch loss is 2.862738870286173e-12 for Epoch #100
# Epoch loss is 2.906831736273512e-18 for Epoch #100
# Epoch loss is 0.00010860722928123976 for Epoch #100
# Epoch loss is 5.405317714729305e-09 for Epoch #100
# Epoch loss is 0.002926909107749229 for Epoch #100
# Epoch loss is 1.9842150401271455e-21 for Epoch #100
# Epoch loss is 2.1072737981601772e-19 for Epoch #100
# Epoch loss is 1.1657774338050472e-07 for Epoch #100
# Epoch loss is 1.3908172464032184e-14 for Epoch #100
# Epoch loss is 0.41827733291140945 for Epoch #100
# Epoch loss is 9.416643060308718e-05 for Epoch #100
# Epoch loss is 1.3575483567644995e-11 for Epoch #100
# Epoch loss is 7.296704707966114e-21 for Epoch #100
# Epoch loss is 2.7390223542298567e-10 for Epoch #100
# Epoch loss is 7.675380136318164e-15 for Epoch #100
# Epoch loss is 0.532889337395375 for Epoch #100
# Epoch loss is 1.998606979084901 for Epoch #100
# Average loss is 0.1865846197215742
# Epoch loss is 1.7134628003096412e-19 for Epoch #100
# Epoch loss is 2.573743522524282e-07 for Epoch #100
# Epoch loss is 0.7948149112319013 for Epoch #100
# Epoch loss is 7.597537317614367e-19 for Epoch #100
# Epoch loss is 0.8966624146234058 for Epoch #100
# Epoch loss is 1.886163641112846e-07 for Epoch #100
# Epoch loss is 8.172581007678764e-18 for Epoch #100
# Epoch loss is 0.09454895585238982 for Epoch #100
# Epoch loss is 0.8514593468526932 for Epoch #100
# Epoch loss is 1.0417489757213478e-12 for Epoch #100
# Epoch loss is 6.728064188055506e-05 for Epoch #100
# Epoch loss is 5.752563105291356e-09 for Epoch #100
# Epoch loss is 0.003600578266670807 for Epoch #100
# Epoch loss is 2.690885788702323e-12 for Epoch #100
# Epoch loss is 2.644736774373482e-18 for Epoch #100
# Epoch loss is 0.00010632050521696406 for Epoch #100
# Epoch loss is 5.145401464869346e-09 for Epoch #100
# Epoch loss is 0.002795878241886906 for Epoch #100
# Epoch loss is 1.758651430199694e-21 for Epoch #100
# Epoch loss is 1.9513522401752942e-19 for Epoch #100
# Epoch loss is 1.0991507757170554e-07 for Epoch #100
# Epoch loss is 1.2907664906122224e-14 for Epoch #100
# Epoch loss is 0.4178223071336863 for Epoch #100
# Epoch loss is 8.942615902390313e-05 for Epoch #100
# Epoch loss is 1.2697862264051576e-11 for Epoch #100
# Epoch loss is 6.7617255148141266e-21 for Epoch #100
# Epoch loss is 2.5324760572493355e-10 for Epoch #100
# Epoch loss is 7.069251532984049e-15 for Epoch #100
# Epoch loss is 0.5347940202659476 for Epoch #100
# Epoch loss is 1.9986089380860455 for Epoch #100
# Average loss is 0.18651236483114014
# Epoch loss is 1.5025727155107466e-19 for Epoch #100
# Epoch loss is 2.601040928654357e-07 for Epoch #100
# Epoch loss is 0.7914927915356846 for Epoch #100
# Epoch loss is 6.743578728150229e-19 for Epoch #100
# Epoch loss is 0.8929000175011019 for Epoch #100
# Epoch loss is 1.7275995418165938e-07 for Epoch #100
# Epoch loss is 7.020711270739581e-18 for Epoch #100
# Epoch loss is 0.09786837797316483 for Epoch #100
# Epoch loss is 0.8519653117953844 for Epoch #100
# Epoch loss is 9.704489278272385e-13 for Epoch #100
# Epoch loss is 6.517445331471084e-05 for Epoch #100
# Epoch loss is 5.629396632094871e-09 for Epoch #100
# Epoch loss is 0.00350771151474829 for Epoch #100
# Epoch loss is 2.5319329045784327e-12 for Epoch #100
# Epoch loss is 2.4095842504305153e-18 for Epoch #100
# Epoch loss is 0.00010414623956821843 for Epoch #100
# Epoch loss is 4.902354244931767e-09 for Epoch #100
# Epoch loss is 0.00267039144521028 for Epoch #100
# Epoch loss is 1.5623173262329267e-21 for Epoch #100
# Epoch loss is 1.8091832001360115e-19 for Epoch #100
# Epoch loss is 1.0368027388655234e-07 for Epoch #100
# Epoch loss is 1.1999221935340856e-14 for Epoch #100
# Epoch loss is 0.4174266489401254 for Epoch #100
# Epoch loss is 8.498043212914679e-05 for Epoch #100
# Epoch loss is 1.1893809375785938e-11 for Epoch #100
# Epoch loss is 6.27471943197015e-21 for Epoch #100
# Epoch loss is 2.3442309007291697e-10 for Epoch #100
# Epoch loss is 6.5221027624848924e-15 for Epoch #100
# Epoch loss is 0.5366015098848527 for Epoch #100
# Epoch loss is 1.99861033037319 for Epoch #100
# Average loss is 0.18644326464714614
# Epoch loss is 1.3215456264882982e-19 for Epoch #100
# Epoch loss is 2.626813960342266e-07 for Epoch #100
# Epoch loss is 0.7882296733699486 for Epoch #100
# Epoch loss is 5.993635498159532e-19 for Epoch #100
# Epoch loss is 0.889100029064822 for Epoch #100
# Epoch loss is 1.58389454714683e-07 for Epoch #100
# Epoch loss is 6.042400400637316e-18 for Epoch #100
# Epoch loss is 0.10125613139848139 for Epoch #100
# Epoch loss is 0.852506889284451 for Epoch #100
# Epoch loss is 9.050448246330438e-13 for Epoch #100
# Epoch loss is 6.31637809934702e-05 for Epoch #100
# Epoch loss is 5.512834652004474e-09 for Epoch #100
# Epoch loss is 0.0034178090118207986 for Epoch #100
# Epoch loss is 2.384775773237291e-12 for Epoch #100
# Epoch loss is 2.1983496356900767e-18 for Epoch #100
# Epoch loss is 0.00010207767913380662 for Epoch #100
# Epoch loss is 4.6748635870524885e-09 for Epoch #100
# Epoch loss is 0.0025502417549883353 for Epoch #100
# Epoch loss is 1.3910318771579497e-21 for Epoch #100
# Epoch loss is 1.6794159706623412e-19 for Epoch #100
# Epoch loss is 9.78432856161649e-08 for Epoch #100
# Epoch loss is 1.1173114730940047e-14 for Epoch #100
# Epoch loss is 0.41708862244497014 for Epoch #100
# Epoch loss is 8.080804621664218e-05 for Epoch #100
# Epoch loss is 1.1156258228264064e-11 for Epoch #100
# Epoch loss is 5.830776078782228e-21 for Epoch #100
# Epoch loss is 2.172487322478332e-10 for Epoch #100
# Epoch loss is 6.02744591435383e-15 for Epoch #100
# Epoch loss is 0.5383133210768967 for Epoch #100
# Epoch loss is 1.998611169523558 for Epoch #100
# Average loss is 0.18637734885899426
# Epoch loss is 1.1657177799748848e-19 for Epoch #100
# Epoch loss is 2.651057697358507e-07 for Epoch #100
# Epoch loss is 0.7850270512717883 for Epoch #100
# Epoch loss is 5.334275231562461e-19 for Epoch #100
# Epoch loss is 0.8852676151279859 for Epoch #100
# Epoch loss is 1.4535862822571067e-07 for Epoch #100
# Epoch loss is 5.210192856777929e-18 for Epoch #100
# Epoch loss is 0.10470907361349983 for Epoch #100
# Epoch loss is 0.8530812058991276 for Epoch #100
# Epoch loss is 8.449944769951031e-13 for Epoch #100
# Epoch loss is 6.12442853842256e-05 for Epoch #100
# Epoch loss is 5.4024540665966694e-09 for Epoch #100
# Epoch loss is 0.003330799167786309 for Epoch #100
# Epoch loss is 2.2484137607550248e-12 for Epoch #100
# Epoch loss is 2.0083719270092518e-18 for Epoch #100
# Epoch loss is 0.00010010844815424621 for Epoch #100
# Epoch loss is 4.461727970817965e-09 for Epoch #100
# Epoch loss is 0.0024352286926037766 for Epoch #100
# Epoch loss is 1.2412915987539171e-21 for Epoch #100
# Epoch loss is 1.5608435941143668e-19 for Epoch #100
# Epoch loss is 9.237636139319435e-08 for Epoch #100
# Epoch loss is 1.0420743919396168e-14 for Epoch #100
# Epoch loss is 0.4168064257125158 for Epoch #100
# Epoch loss is 7.688945206578144e-05 for Epoch #100
# Epoch loss is 1.0478883217598113e-11 for Epoch #100
# Epoch loss is 5.425664976660227e-21 for Epoch #100
# Epoch loss is 2.0156364635908275e-10 for Epoch #100
# Epoch loss is 5.57956965035836e-15 for Epoch #100
# Epoch loss is 0.5399311026232844 for Epoch #100
# Epoch loss is 1.9986114686154208 for Epoch #100
# Average loss is 0.18631462419432368

# %%
plt.plot(np.arange(0,100),lossHistory)

# %%
def predict(X):
  for i in np.random.choice(300,10):
    
    y=np.dot(X[i],W)
    pred=Sigmoid(y)
    if pred<0.5:
      print("label 0")
    else:
      print("label 1")

# %%
predict(X_bias)
# Out:
# label 1
# label 1
# label 1
# label 0
# label 0
# label 0
# label 1
# label 1
# label 1
# label 0

# %%
Y = (-W[0] - (W[1] * X)) / W[2]
plt.figure()
plt.scatter(X[:,0],X[:,1],c="y")
plt.plot(X,Y,"r-")
# Out:
# [<matplotlib.lines.Line2D at 0x7fcba9c4c048>,
#  <matplotlib.lines.Line2D at 0x7fcba9ce5748>]
